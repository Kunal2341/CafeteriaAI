# %% [markdown]
# # Using a model, live video detection

# %% [markdown]
# # Not working - save vid

# %%
test_path = '/Users/NidhiAneja/Documents/AI/IMAGE_AI/ImageAI-master/MODELS'

# %%
from imageai.Detection import VideoObjectDetection
import os
import cv2

# %%
camera = cv2.VideoCapture(0)
detector = VideoObjectDetection()
detector.setModelTypeAsYOLOv3()
detector.setModelPath(os.path.join(test_path , "yolo.h5"))
detector.loadModel()
video_path = detector.detectObjectsFromVideo(camera_input=camera,
                                             output_file_path=os.path.join(test_path, "camera_detected_video"), 
                                             frames_per_second=20, 
                                             log_progress=True, 
                                             minimum_percentage_probability=30)
print(video_path)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-bc409f4dd3a9> in <module>()
#       4 detector.setModelTypeAsYOLOv3()
#       5 detector.setModelPath(os.path.join(test_path , "yolo.h5"))
# ----> 6 detector.loadModel()
#       7 video_path = detector.detectObjectsFromVideo(camera_input=camera,
#       8                                              output_file_path=os.path.join(test_path, "camera_detected_video"),
#
# /anaconda3/lib/python3.6/site-packages/imageai/Detection/__init__.py in loadModel(self, detection_speed)
#    1021             elif (self.__modelType == "yolov3"):
#    1022                 model = yolo_main(Input(shape=(None, None, 3)), len(self.__yolo_anchors) // 3,
# -> 1023                                   len(self.numbers_to_names))
#    1024                 model.load_weights(self.modelPath)
#    1025
#
# ...

# %%
camera.release()
